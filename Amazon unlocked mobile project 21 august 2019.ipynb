# %%
import numpy as np
import pandas as pd
data_set=pd.read_csv(r"C:\Users\USER\Desktop\Amazon_Unlocked_Mobile.csv")

# %%
data_set=data_set[0:100]

# %%
data_set
# Out:
#                                          Product Name Brand Name   Price  \
# 0   "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1   "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2   "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3   "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4   "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 5   "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 6   "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 7   "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 8   "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 9   "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 10  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 11  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 12  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 13  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 14  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 15  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 16  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 17  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 18  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 19  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 20  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 21  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 22  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 23  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 24  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 25  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 26  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 27  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 28  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 29  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# ..                                                ...        ...     ...
# 70  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 71  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 72  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 73  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 74  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 75  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 76  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 77  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 78  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 79  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 80  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 81  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 82  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 83  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 84  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 85  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 86  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 87  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 88  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 89  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 90  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 91  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 92  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 93  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 94  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 95  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 96  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 97  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 98  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 99  "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
#
#     Rating                                            Reviews  Review Votes
# 0        5  I feel so LUCKY to have found this used (phone...           1.0
# 1        4  nice phone, nice up grade from my pantach revu...           0.0
# 2        5                                       Very pleased           0.0
# 3        4  It works good but it goes slow sometimes but i...           0.0
# 4        4  Great phone to replace my lost phone. The only...           0.0
# 5        1  I already had a phone with problems... I know ...           1.0
# 6        2  The charging port was loose. I got that solder...           0.0
# 7        2  Phone looks good but wouldn't stay charged, ha...           0.0
# 8        5  I originally was using the Samsung S2 Galaxy f...           0.0
# 9        3  It's battery life is great. It's very responsi...           0.0
# 10       3  My fiance had this phone previously, but cause...           0.0
# 11       5  This is a great product it came after two days...           0.0
# 12       5  These guys are the best! I had a little situat...           2.0
# 13       1  I'm really disappointed about my phone and ser...           1.0
# 14       5  Ordered this phone as a replacement for the sa...           1.0
# 15       2  Had this phone before and loved it but was not...           0.0
# 16       5  I was able to get the phone I previously owned...           6.0
# 17       5  I brought this phone as a replacement for my d...           0.0
# 18       4  I love the phone. It does everything I need an...           1.0
# 19       3  unfortunately Sprint could not activate the ph...           0.0
# 20       4  The battery was old & had been over used becau...           0.0
# 21       4  pros-beautiful screen,capable of running chrom...           0.0
# 22       1  I purchased this phone in December as a christ...          19.0
# 23       4  Phone good just a little slow phone old but it...           0.0
# 24       4  Phone's speaker little low. Overall very happy...           0.0
# 25       5  the phone was great and in good condition. My ...           0.0
# 26       3  the reasons for the 3 star rating was it was i...           0.0
# 27       5              Phone works great. No problems at all           0.0
# 28       1       was not in good condition but does work good           0.0
# 29       1  Just... not good. The phone has great screen r...           0.0
# ..     ...                                                ...           ...
# 70       5  This is a solidly-built unlocked phone that is...          17.0
# 71       1  Hola, compramos dos teléfonos y vienieron tota...           2.0
# 72       5  THIS CELLPHONE IS VERY EASY FOR USING, IT HAS ...           4.0
# 73       5  GRACIAS ME LLEGO EL PROCTO QUE COMPRE Y LLEVO ...           0.0
# 74       4  Freezes alot. But i bought primarily for playi...           1.0
# 75       4  The keys are a little hard to hit, and I didn'...           0.0
# 76       2  Preface: This is not what would be considered ...           9.0
# 77       5  We just received the phone a few days ago. Put...           3.0
# 78       5  I bought this phone as a Christmas present for...           3.0
# 79       4  The Phone is pretty good. I am using it with a...           2.0
# 80       5  loved everything about it. also it looks like ...           1.0
# 81       5  THIS IS A SOLUTION IF YOU WANT YOU ARE LOOKING...           2.0
# 82       5  This phone in an excellent phone at a great pr...           1.0
# 83       3  Have problems setting correct time on Nokia As...           5.0
# 84       4  This is a good phone although it seems to have...           1.0
# 85       5  I've been a long time user of the iPhone. I fi...           2.0
# 86       5  This phone, like all of Nokia's feature phones...          12.0
# 87       5                                           Love it.           0.0
# 88       2  Sorry it took so long to Reply or Review this ...           0.0
# 89       5  Bought it as a gift for my Mum and she loves i...           0.0
# 90       1  Incredible! This phone does not have Splaniish...           0.0
# 91       1                                                BAD           0.0
# 92       5                                               good           0.0
# 93       1         The battery died in less than 24/hours....           0.0
# 94       5                                 Excellent Product.           0.0
# 95       5                                          very well           0.0
# 96       1                      Cannot connect to GSM network           0.0
# 97       4  This cell phone exceeded my expectations, it's...           1.0
# 98       4  pros.. it works fine, its easy to use, not too...           1.0
# 99       5  I went through lots of reviews for different p...           1.0
#
# [100 rows x 6 columns]

# %%
unique_words=[]  
total_words=[]  
for i in data_set['Reviews']:  
    i = str(i)  #float to char
    for j in i.split():  
        total_words.append(j)  
        if j not in unique_words:  
            unique_words.append(j)  
len(unique_words),len(total_words)
# Out:
# (1549, 4643)

# %%
x=[]  
for i in unique_words:  
    count=0  
    for j in data_set['Reviews']:  
        for k in j.split():  
            if i==k:
                count=count+1  
    x.append([i,count])

# %%
x
# Out:
# [['I', 142],
#  ['feel', 1],
#  ['so', 18],
#  ['LUCKY', 1],
#  ['to', 125],
#  ['have', 29],
#  ['found', 4],
#  ['this', 48],
#  ['used', 9],
#  ['(phone', 1],
#  ['us', 1],
#  ['&', 9],
#  ['not', 34],
#  ['hard', 3],
#  ['at', 12],
#  ['all),', 1],
#  ['phone', 106],
#  ['on', 24],
#  ['line', 1],
#  ['from', 15],
#  ['someone', 2],
#  ['who', 6],
#  ['upgraded', 2],
#  ['and', 109],
#  ['sold', 3],
#  ['one.', 3],
#  ['My', 5],
#  ['Son', 1],
#  ['liked', 4],
#  ['his', 1],
#  ['old', 8],
#  ['one', 14],
#  ['that', 42],
#  ['finally', 2],
#  ['fell', 1],
#  ['apart', 1],
#  ['after', 3],
#  ['2.5+', 1],
#  ['years', 3],
#  ["didn't", 7],
#  ['want', 13],
#  ['an', 15],
#  ['upgrade!!', 1],
#  ['Thank', 2],
#  ['you', 26],
#  ['Seller,', 1],
#  ['we', 6],
#  ['really', 13],
#  ['appreciate', 1],
#  ['it', 89],
#  ['your', 5],
#  ['honesty', 1],
#  ['re:', 1],
#  ['said', 3],
#  ['phone.I', 1],
#  ['recommend', 7],
#  ['seller', 4],
#  ['very', 20],
#  ['highly', 2],
#  ['would', 17],
#  ['but', 41],
#  ['them', 4],
#  ['again!!', 1],
#  ['nice', 7],
#  ['phone,', 6],
#  ['up', 10],
#  ['grade', 1],
#  ['my', 41],
#  ['pantach', 1],
#  ['revue.', 1],
#  ['Very', 4],
#  ['clean', 2],
#  ['set', 5],
#  ['easy', 7],
#  ['up.', 2],
#  ['never', 3],
#  ['had', 19],
#  ['android', 2],
#  ['they', 6],
#  ['are', 19],
#  ['fantastic', 1],
#  ['say', 3],
#  ['the', 190],
#  ['least.', 1],
#  ['perfect', 2],
#  ['size', 3],
#  ['for', 61],
#  ['surfing', 1],
#  ['social', 5],
#  ['media.', 1],
#  ['great', 21],
#  ['samsung', 1],
#  ['pleased', 2],
#  ['It', 16],
#  ['works', 12],
#  ['good', 25],
#  ['goes', 4],
#  ['slow', 2],
#  ['sometimes', 2],
#  ['its', 6],
#  ['a', 128],
#  ['love', 5],
#  ['Great', 3],
#  ['replace', 1],
#  ['lost', 3],
#  ['phone.', 19],
#  ['The', 42],
#  ['only', 10],
#  ['thing', 3],
#  ['is', 87],
#  ['volume', 1],
#  ['button', 2],
#  ['does', 12],
#  ['work,', 2],
#  ['can', 15],
#  ['still', 8],
#  ['go', 5],
#  ['into', 9],
#  ['settings', 1],
#  ['adjust.', 1],
#  ['Other', 2],
#  ['than', 9],
#  ['that,', 2],
#  ['job', 2],
#  ['until', 3],
#  ['am', 10],
#  ['eligible', 1],
#  ['upgrade', 1],
#  ['again.Thaanks!', 1],
#  ['already', 1],
#  ['with', 42],
#  ['problems...', 1],
#  ['know', 2],
#  ['stated', 1],
#  ['was', 47],
#  ['used,', 1],
#  ['dang,', 1],
#  ['did', 3],
#  ['state', 2],
#  ['charge.', 2],
#  ['wish', 2],
#  ['read', 2],
#  ['these', 6],
#  ['comments', 1],
#  ['then', 3],
#  ['purchased', 4],
#  ['item....', 1],
#  ['cracked', 1],
#  ['side..', 1],
#  ['damaged', 1],
#  ['goods', 2],
#  ['what', 6],
#  ['is....', 1],
#  ['If', 7],
#  ['trying', 2],
#  ['charge', 1],
#  ['another', 8],
#  ['way', 4],
#  ['work', 7],
#  ['requesting', 1],
#  ['money', 1],
#  ['back...', 1],
#  ['AND', 4],
#  ['WILL', 1],
#  ['GET', 1],
#  ['MY', 1],
#  ['MONEY', 1],
#  ['BACK...SIGNED', 1],
#  ['AN', 1],
#  ['UNHAPPY', 1],
#  ['CUSTOMER....', 1],
#  ['charging', 2],
#  ['port', 1],
#  ['loose.', 1],
#  ['got', 5],
#  ['soldered', 1],
#  ['in.', 3],
#  ['Then', 2],
#  ['needed', 4],
#  ['new', 5],
#  ['battery', 10],
#  ['as', 32],
#  ['well.', 4],
#  ['$100', 1],
#  ['later', 1],
#  ['(not', 1],
#  ['including', 1],
#  ['cost', 1],
#  ['of', 59],
#  ['purchase)', 1],
#  ['usable', 1],
#  ['should', 3],
#  ['been', 9],
#  ['in', 33],
#  ['Phone', 9],
#  ['looks', 3],
#  ["wouldn't", 2],
#  ['stay', 2],
#  ['charged,', 1],
#  ['buy', 5],
#  ['battery.', 1],
#  ['Still', 1],
#  ["couldn't", 3],
#  ['charged', 1],
#  ['long.so', 1],
#  ['trashed', 1],
#  ['it.MONEY', 1],
#  ['lost,', 1],
#  ['again', 3],
#  ['will', 7],
#  ['person!', 1],
#  ['!!!', 1],
#  ['originally', 1],
#  ['using', 3],
#  ['Samsung', 3],
#  ['S2', 1],
#  ['Galaxy', 2],
#  ['Sprint', 4],
#  ['wanted', 3],
#  ['return', 4],
#  ['back', 9],
#  ['EPIC', 1],
#  ['4G', 1],
#  ['because', 7],
#  ['missed', 1],
#  ['keyboard,', 2],
#  ['smaller', 1],
#  ['compact', 1],
#  ['some', 5],
#  ['basic', 3],
#  ['functions', 5],
#  ['smart', 7],
#  ['(i.e.', 1],
#  ['checking', 1],
#  ['e-mail,', 2],
#  ['getting', 4],
#  ['directions,', 2],
#  ['text', 3],
#  ['messaging)', 1],
#  ['Because', 2],
#  ['powerful', 1],
#  ['newer', 1],
#  ['cell', 5],
#  ['phones', 11],
#  ['out', 10],
#  ['there,', 1],
#  ['just', 9],
#  ['be', 20],
#  ['aware', 2],
#  ['more', 6],
#  ['applications', 1],
#  ['install', 1],
#  ['slower', 1],
#  ['runs', 4],
#  ['most', 3],
#  ['likely', 1],
#  ['freeze', 1],
#  ['time', 4],
#  ['time.', 2],
#  ['But', 5],
#  ['camera', 5],
#  ['great,', 1],
#  ['video', 2],
#  ['well,', 2],
#  ['even', 7],
#  ['web', 3],
#  ['browsing', 1],
#  ['decent', 2],
#  ['gives', 2],
#  ['me', 11],
#  ['need.', 1],
#  ['also', 7],
#  ['notice', 1],
#  ['life', 4],
#  ['lasts', 1],
#  ['little', 10],
#  ['bit', 4],
#  ['longer', 3],
#  ['much', 3],
#  ['quicker', 1],
#  ['S2.', 1],
#  ["It's", 5],
#  ['great.', 5],
#  ['responsive', 1],
#  ['touch.', 1],
#  ['issue', 4],
#  ['screen', 4],
#  ['black', 1],
#  ['press', 1],
#  ['top', 1],
#  ['several', 1],
#  ['times', 2],
#  ['get', 10],
#  ['re-illuminate.', 1],
#  ['fiance', 1],
#  ['previously,', 1],
#  ['caused', 1],
#  ['many', 3],
#  ['problems.', 2],
#  ['So,', 1],
#  ['course,', 1],
#  ['decided', 1],
#  ['browse', 1],
#  ['amazon', 2],
#  ['replacement', 3],
#  ["til'", 1],
#  ['our', 1],
#  ['contract', 2],
#  ['up!', 1],
#  ['far', 3],
#  ['good!', 1],
#  ['This', 15],
#  ['product', 5],
#  ['came', 6],
#  ['two', 2],
#  ['days', 2],
#  ['ordering', 1],
#  ['it.', 14],
#  ['There', 4],
#  ['blemish', 1],
#  ['side,but', 1],
#  ['cares', 1],
#  ['long', 4],
#  ['fullly', 1],
#  ['functional.i', 1],
#  ['anyone', 1],
#  ['reading', 1],
#  ['this.', 1],
#  ['These', 1],
#  ['guys', 1],
#  ['best!', 1],
#  ['situation', 1],
#  ['item', 1],
#  ['quickly', 2],
#  ['fixed', 1],
#  ['issue.', 2],
#  ['definitely', 4],
#  ['buying', 3],
#  ['phon', 1],
#  ['if', 12],
#  ['need', 6],
#  ["I'm", 8],
#  ['disappointed', 1],
#  ['about', 4],
#  ['service.', 2],
#  ['went', 3],
#  ['over', 3],
#  ['week', 2],
#  ['ago.', 3],
#  ['Instead', 1],
#  ['handling', 1],
#  ['when', 5],
#  ['first', 4],
#  ['surfaced.', 1],
#  ["I've", 7],
#  ['told', 4],
#  ['do', 8],
#  ['that.', 2],
#  ['Now', 3],
#  ['stick', 1],
#  ['no', 6],
#  ['55', 1],
#  ['dollars', 2],
#  ['service', 2],
#  ['using.', 1],
#  ["haven't", 2],
#  ['received', 4],
#  ['mailing', 1],
#  ['label', 1],
#  ['item.', 1],
#  ['purchase', 3],
#  ['amazon.', 1],
#  ['rushing', 1],
#  ['use', 17],
#  ['theirs', 1],
#  ['or', 17],
#  ['smartphones', 1],
#  ['288', 1],
#  ['business', 1],
#  ['Anytime', 1],
#  ['soon.', 2],
#  ['thought', 1],
#  ['deal', 2],
#  ['seems', 4],
#  ['like', 14],
#  ['lucked', 1],
#  ['out.', 1],
#  ['Ordered', 1],
#  ['same', 4],
#  ['model', 1],
#  ['expires', 1],
#  ['Seller', 2],
#  ['confirmation', 1],
#  ['delivery', 1],
#  ['could', 7],
#  ['take', 4],
#  ['7', 1],
#  ['days.', 1],
#  ['sent', 2],
#  ['within', 1],
#  ['hours', 1],
#  ['receiving', 2],
#  ['order', 1],
#  ['next', 1],
#  ['day.', 1],
#  ['better', 4],
#  ['described', 1],
#  ['able', 6],
#  ['transfer', 1],
#  ['data', 7],
#  ['Highly', 1],
#  ['Had', 1],
#  ['before', 3],
#  ['loved', 2],
#  ['working', 2],
#  ['One', 2],
#  ['SD', 4],
#  ['card', 9],
#  ['slot', 1],
#  ['open', 2],
#  ['try', 1],
#  ['access', 3],
#  ['file', 1],
#  ['managment,', 1],
#  ['show', 1],
#  ['computer.', 1],
#  ['fine', 2],
#  ['Trying', 1],
#  ['trouble', 1],
#  ['shoot', 1],
#  ['now.', 2],
#  ['previously', 1],
#  ['owned...with', 1],
#  ['keyboard', 7],
#  ['touch', 4],
#  ['screen.', 3],
#  ['best', 5],
#  ['device', 1],
#  ['provider,', 1],
#  ['well', 6],
#  ['worth', 3],
#  ['brought', 1],
#  ['daughter,', 1],
#  ['phones.', 2],
#  ['must', 1],
#  ['purchase.', 1],
#  ['wonderful.', 1],
#  ['everything', 4],
#  ['four', 1],
#  ['through', 4],
#  ['shipped', 1],
#  ["Amazon's", 2],
#  ['warehouse.', 1],
#  ['problem', 7],
#  ['come', 3],
#  ['micro', 1],
#  ['sd', 2],
#  ['card.', 5],
#  ['No', 5],
#  ['problems', 5],
#  ['activated', 1],
#  ['Sprint.', 1],
#  ['unfortunately', 1],
#  ['activate', 2],
#  ['due', 1],
#  ['blocking', 1],
#  ['matter', 1],
#  ['handled', 1],
#  ['quickly.', 1],
#  ['satisfied', 2],
#  ['barely', 3],
#  ['holds', 2],
#  ['Otherwise,', 1],
#  ['issues', 2],
#  ['itself.', 1],
#  ['pros-beautiful', 1],
#  ['screen,capable', 1],
#  ['running', 2],
#  ['chrome,take', 1],
#  ['pictures,the', 1],
#  ['comfy,fits', 1],
#  ['pocket', 4],
#  ['fit', 2],
#  ['hands,plays', 1],
#  ['videos', 1],
#  ['gamescons-no', 1],
#  ['Bluetooth,came', 1],
#  ['late,run', 1],
#  ['down', 3],
#  ['fast', 3],
#  ['quick,doesnt', 1],
#  ['play', 1],
#  ['1080p', 1],
#  ['videos.but', 1],
#  ['those', 3],
#  ['talk', 1],
#  ['lot', 5],
#  ['watch', 1],
#  ['movies', 1],
#  ['December', 1],
#  ['christmas', 1],
#  ['present', 2],
#  ['son.', 1],
#  ['called', 2],
#  ['sprint', 1],
#  ['find', 3],
#  ['ESN', 5],
#  ["wasn't", 4],
#  ['clear.', 5],
#  ['store', 3],
#  ['upon', 1],
#  ['research', 1],
#  ['reached', 1],
#  ['company', 1],
#  ['inform', 1],
#  ['clean.', 1],
#  ['send', 4],
#  ['asked', 2],
#  ['representative', 2],
#  ['provide', 1],
#  ['#', 1],
#  ['call', 2],
#  ['make', 1],
#  ['sure', 2],
#  ['available', 1],
#  ['guaranteed', 1],
#  ["should've", 1],
#  ['known', 1],
#  ['something', 4],
#  ['wrong', 1],
#  ['then.', 1],
#  ['second', 1],
#  ['turned', 2],
#  ['clear', 3],
#  ['ESN.', 2],
#  ['informed', 1],
#  ["isn't", 5],
#  ['So', 3],
#  ['once', 1],
#  ['back.', 1],
#  ['refund', 3],
#  ['shipping', 1],
#  ['since', 5],
#  ['yet', 2],
#  ['see', 3],
#  ['shipping.', 1],
#  ['suggest', 1],
#  ['anything', 2],
#  ['them.', 3],
#  ["it's", 9],
#  ['temporary', 1],
#  ['right', 1],
#  ['thank', 1],
#  ["Phone's", 1],
#  ['speaker', 1],
#  ['low.', 1],
#  ['Overall', 1],
#  ['happy', 2],
#  ['Chubbietech.', 1],
#  ['satisfied.', 1],
#  ['condition.', 1],
#  ['Daughter', 1],
#  ['andriod', 1],
#  ['user', 5],
#  ['now', 2],
#  ['!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', 1],
#  ['reasons', 1],
#  ['3', 2],
#  ['star', 1],
#  ['rating', 1],
#  ['opinion', 1],
#  ['iphone', 2],
#  ['4s', 1],
#  ['tends', 1],
#  ['randomly', 2],
#  ['crash,', 1],
#  ['power', 1],
#  ['off', 3],
#  ['storage', 2],
#  ['space,', 1],
#  ['usage,', 1],
#  ['all', 13],
#  ['condition', 2],
#  ['Just...', 1],
#  ['good.', 3],
#  ['has', 18],
#  ['resolution,', 2],
#  ['low,', 1],
#  ['anything.', 1],
#  ['May', 1],
#  ["don't", 10],
#  ['expect', 2],
#  ['things', 5],
#  ['Freedompop.', 1],
#  ['described,', 1],
#  ['ship!', 1],
#  ['Perfect', 1],
#  ['every', 3],
#  ['way.', 1],
#  ['bad', 3],
#  ['charger', 2],
#  ['port.', 1],
#  ['Just', 2],
#  ['use.', 3],
#  ['gotten', 1],
#  ['replacement.it', 1],
#  ['while', 2],
#  ['lasted.', 1],
#  ['condition!', 1],
#  ['price', 3],
#  ['brings', 1],
#  ['memories', 1],
#  ['owning', 2],
#  ['phone!', 1],
#  ['Met', 1],
#  ['expectations.', 1],
#  ["can't", 4],
#  ['complain', 1],
#  ['all.', 1],
#  ['price!', 2],
#  ['on,', 1],
#  ['planning', 1],
#  ['whatsapp', 1],
#  ['anyway.', 1],
#  ['oh', 1],
#  ['problem,', 1],
#  ['change', 1],
#  ['idiom', 1],
#  ['excellent', 5],
#  ['excelente', 3],
#  ['bought', 6],
#  ['mom', 1],
#  ['she', 4],
#  ['loves', 2],
#  ['arabian', 1],
#  [':(', 2],
#  ['only............once', 1],
#  ['mic', 1],
#  ["that's", 2],
#  ['mic.', 1],
#  ['beating.', 1],
#  ['it!', 1],
#  ['practical', 1],
#  ['user-friendly', 1],
#  ['Sharp', 1],
#  ['classy', 1],
#  ['100%', 1],
#  ['gooddd!', 1],
#  ['Shipped', 1],
#  ['exactly', 1],
#  ['expected!', 1],
#  ['Works', 1],
#  ['wonderful', 1],
#  ['Bought', 3],
#  ['alternative', 1],
#  ['plan.', 3],
#  ['Go-Phone', 1],
#  ['pay-as-you-go', 1],
#  ['radio', 3],
#  ['music', 3],
#  ['players', 1],
#  ['sound', 3],
#  ['quality.', 1],
#  ['type', 3],
#  ['features', 9],
#  ['easier', 1],
#  ['faster', 1],
#  ['any', 4],
#  ['used.', 1],
#  ['software', 2],
#  ['glitches', 1],
#  ['documented', 1],
#  ['Nokia', 25],
#  ['support', 3],
#  ['site', 1],
#  ['which', 10],
#  ['proved', 1],
#  ['easily', 2],
#  ['fixed.', 1],
#  ['Even', 2],
#  ['though', 2],
#  ['based', 1],
#  ['supported', 1],
#  ['by', 3],
#  ['Microsoft,', 1],
#  ['accessing', 1],
#  ['directly', 1],
#  ['via', 1],
#  ['WIFI', 1],
#  ['connection', 1],
#  ['-', 5],
#  ['pay', 2],
#  ['privilege', 1],
#  ['launching', 2],
#  ['site/application', 1],
#  ['there.', 1],
#  ['Although', 1],
#  ['browser', 4],
#  ['pretty', 8],
#  ['Spartan', 1],
#  ['appearance,', 1],
#  ['stability.', 1],
#  ['big', 5],
#  ['guy', 1],
#  ['lands', 1],
#  ['large', 2],
#  ['full', 2],
#  ['qwerty', 2],
#  ['programmable', 1],
#  ['hot', 1],
#  ['keys', 5],
#  ['on-screen', 1],
#  ['shortcuts.', 1],
#  ['Keeps', 1],
#  ['items', 1],
#  ['require', 1],
#  ['connections', 1],
#  ['accident.', 1],
#  ['lighting', 1],
#  ['thorough', 1],
#  ['raised', 1],
#  ['buttons', 1],
#  ['tactile', 1],
#  ['positive', 1],
#  ['click', 1],
#  ['response.', 1],
#  ['few', 2],
#  ['quirks.', 1],
#  ['airplane', 1],
#  ['mode', 1],
#  ['tell.', 1],
#  ['flight', 1],
#  ['profile', 1],
#  ["doesn't", 2],
#  ['seem', 2],
#  ['broadcasting', 1],
#  ['off.', 1],
#  ['main', 1],
#  ['navigation', 1],
#  ['button/mouse', 1],
#  ['small', 4],
#  ['always', 4],
#  ['respond', 1],
#  ['expected', 1],
#  ['might', 1],
#  ['though.', 1],
#  ['All', 1],
#  ['vendor', 1],
#  ['GPS', 2],
#  ['bill', 2],
#  ['month', 1],
#  ['bunch', 1],
#  ['keep', 1],
#  ['smoothly.', 1],
#  ['muy', 2],
#  ['buen', 1],
#  ['producto', 1],
#  ['trapped', 1],
#  ['2001,', 1],
#  ['simple', 2],
#  ['school', 1],
#  ['flip', 1],
#  ['blackberry', 1],
#  ['somthing', 1],
#  ['new.', 1],
#  ['middle', 1],
#  ['two,', 1],
#  ['dimension.', 1],
#  ['Nothing', 1],
#  ['frustration', 2],
#  ['Excellent', 3],
#  ['A', 4],
#  ['friend', 1],
#  ['mentioned', 1],
#  ['he', 1],
#  ['said.', 1],
#  ['Thanks', 1],
#  ['friend.', 1],
#  ['Used', 1],
#  ['unlocked', 4],
#  ['GSM', 4],
#  ['Asha', 8],
#  ['302', 7],
#  ['Philippines', 2],
#  ['recently', 1],
#  ['(Jan-Feb', 1],
#  ['2015).', 1],
#  ['Excellent,', 1],
#  ['functionality.', 1],
#  ['P40', 1],
#  ['SIM', 2],
#  ['airport', 1],
#  ['presto!', 1],
#  ['worked.', 1],
#  ['passed', 1],
#  ['brother', 1],
#  ['instant', 1],
#  ['US.', 1],
#  ['He', 1],
#  ['visiting', 1],
#  ['Having', 2],
#  ['w/', 2],
#  ['screen,', 2],
#  ['surprised', 2],
#  ['myself', 2],
#  ['worked', 1],
#  ['having', 1],
#  ['instructions', 1],
#  ['operate', 1],
#  ["I'll", 3],
#  ['version', 1],
#  ['Excelente', 3],
#  ['youngest', 1],
#  ['son,', 1],
#  ['walk', 1],
#  ['reasonable', 1],
#  ['options,', 1],
#  ['quality', 2],
#  ['solid', 1],
#  ['Good', 1],
#  ['choice', 1],
#  ['perfect,', 1],
#  ['practical,', 1],
#  ['handle,', 1],
#  ['packed', 1],
#  ['!!....all', 1],
#  ['right....i', 1],
#  ['recommend....', 1],
#  ['brand', 1],
#  ['telephone,', 1],
#  ['price,', 2],
#  ['team,', 1],
#  ['gift', 2],
#  ['daughter', 1],
#  ['it,', 2],
#  ['affordable', 1],
#  ['First', 1],
#  ['off,', 1],
#  ['let', 2],
#  ['age', 1],
#  ['16,', 1],
#  ['ten', 1],
#  ['Of', 1],
#  ['course', 1],
#  ['there', 1],
#  ['year', 1],
#  ['where', 1],
#  ['ventured', 1],
#  ['land', 1],
#  ['died', 2],
#  ['went.', 1],
#  ['enjoyed', 1],
#  ['phones.Second,', 1],
#  ['looking', 5],
#  ['QWERTY', 2],
#  ['internet/video/mp3', 1],
#  ['playing', 3],
#  ['capabilities', 1],
#  ['fits', 2],
#  ['strong', 3],
#  ['build,', 1],
#  ['dropped', 1],
#  ['numerous', 1],
#  ['intact.', 1],
#  ['fan', 1],
#  ['touchscreens', 1],
#  ['(which', 3],
#  ['why', 1],
#  ['303).', 1],
#  ['As', 1],
#  ['think', 2],
#  ['depends', 1],
#  ['headphones.', 1],
#  ['earbuds', 1],
#  ['produced', 1],
#  ['loudness', 2],
#  ['93', 1],
#  ['decibels', 1],
#  ['made', 2],
#  ['listening', 1],
#  ['experience', 2],
#  ['mediocre', 1],
#  ['buds', 1],
#  ['110', 1],
#  ['db', 1],
#  ['better.', 1],
#  ['Xpress', 1],
#  ['sucky', 1],
#  ['downloaded', 1],
#  ['Opera', 2],
#  ['slightly', 1],
#  ['internet', 4],
#  ['easy.', 1],
#  ["won't", 1],
#  ['games', 1],
#  ['SNS', 1],
#  ['PC', 1],
#  ['reason', 1],
#  ['phone.My', 1],
#  ['built', 2],
#  ['antenna', 1],
#  ['listen', 1],
#  ['re', 1],
#  ['without', 5],
#  ['RDS', 1],
#  ['earbuds.', 1],
#  ['move', 1],
#  ['Blackberrys', 1],
#  ['start', 2],
#  ['with.EDIT', 1],
#  ['(October', 1],
#  ['3,', 1],
#  ['2013):', 1],
#  ['Gino', 1],
#  ['25cm', 1],
#  ['4', 1],
#  ['Section', 1],
#  ['Telescoping', 1],
#  ['Stainless', 1],
#  ['Steel', 1],
#  ['AM', 2],
#  ['FM', 1],
#  ['Radio', 1],
#  ['Antenna', 1],
#  ['3.5mm', 1],
#  ['Plug', 1],
#  ['speaker.', 1],
#  ['enjoying', 1],
#  ['sitting', 1],
#  ['outside', 1],
#  ['friends', 1],
#  ['desk.', 1],
#  ['Unlocked', 1],
#  ['3.2MP', 1],
#  ['Camera,', 1],
#  ['Video,', 1],
#  ['QWERTYDependableTraditional', 1],
#  ["Menu'sNot", 1],
#  ['Complicated', 1],
#  ["'Smart", 1],
#  ["Phones'DurableEasy", 1],
#  ['Straighttalk,', 1],
#  ['Internet,', 1],
#  ['WiFi,', 1],
#  ['Bluetooth.', 1],
#  ['solidly-built', 1],
#  ['update', 4],
#  ['popular', 1],
#  ['C3.', 1],
#  ['S40', 2],
#  ['bads.', 1],
#  ['reception', 2],
#  ['audio.', 1],
#  ['3g', 1],
#  ['supports', 1],
#  ['850', 1],
#  ['1900', 2],
#  ['bands', 1],
#  ['(AT&T', 1],
#  ['T-mobile', 1],
#  ['hspa', 1],
#  ['refarmed', 1],
#  ['1700/2100', 1],
#  ['pcs', 1],
#  ['band.)', 1],
#  ['+', 1],
#  ['2100', 1],
#  ['band.The', 1],
#  ['good,', 1],
#  ['firm', 1],
#  ['other', 6],
#  ['(e.g.', 1],
#  ['E5),', 1],
#  ['comparable', 1],
#  ['C3', 1],
#  ['keyboard.', 4],
#  ['obviously', 1],
#  ['world', 1],
#  ['market,', 1],
#  ['added', 1],
#  ['European', 1],
#  ['chars', 1],
#  ['symbols', 1],
#  ['keypad.', 1],
#  ['Wi-fi', 1],
#  ['fine,', 2],
#  ['Mini', 1],
#  ['installed', 1],
#  ['web-surfing.', 1],
#  ['tried', 1],
#  ['e-mail', 2],
#  ['clients.', 1],
#  ['Text', 1],
#  ['messaging', 1],
#  ["'normal'", 1],
#  ['in-box', 1],
#  ['conversation', 1],
#  ['modes.', 1],
#  ['OVI', 1],
#  ['app', 3],
#  ...]

# %%
len(x)
# Out:
# 1549

# %%
### removing stopwords from string

# %%
import nltk
from nltk.corpus import stopwords  
from nltk.tokenize import word_tokenize  
 
example_sent = "This is a sample sentence, showing off the stop words filtration."  
 
stop_words = set(stopwords.words('english'))  
 
word_tokens = word_tokenize(example_sent)  
 
filtered_sentence = [w for w in word_tokens if not w in stop_words]  
 
filtered_sentence = []  
 
for w in word_tokens: 
    if w not in stop_words:  
        filtered_sentence.append(w)  
 
print(word_tokens)  
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ['This', 'sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration', '.']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# import these modules  
from nltk.stem import PorterStemmer  
from nltk.tokenize import word_tokenize  
 
ps = PorterStemmer()  
 
# choose some words to be stemmed  
words = ["program", "programs", "programer", "programing", "programers"]  
 
for w in words:  
    print(w, " : ", ps.stem(w))
# Out:
# program  :  program
# programs  :  program
# programer  :  program
# programing  :  program
# programers  :  program

# %%
data_set.columns
# Out:
# Index(['Product Name', 'Brand Name', 'Price', 'Rating', 'Reviews',
#        'Review Votes'],
#       dtype='object')

# %%
y=data_set['Rating']
x=data_set['Reviews']

# %%
x
# Out:
# 0     I feel so LUCKY to have found this used (phone...
# 1     nice phone, nice up grade from my pantach revu...
# 2                                          Very pleased
# 3     It works good but it goes slow sometimes but i...
# 4     Great phone to replace my lost phone. The only...
# 5     I already had a phone with problems... I know ...
# 6     The charging port was loose. I got that solder...
# 7     Phone looks good but wouldn't stay charged, ha...
# 8     I originally was using the Samsung S2 Galaxy f...
# 9     It's battery life is great. It's very responsi...
# 10    My fiance had this phone previously, but cause...
# 11    This is a great product it came after two days...
# 12    These guys are the best! I had a little situat...
# 13    I'm really disappointed about my phone and ser...
# 14    Ordered this phone as a replacement for the sa...
# 15    Had this phone before and loved it but was not...
# 16    I was able to get the phone I previously owned...
# 17    I brought this phone as a replacement for my d...
# 18    I love the phone. It does everything I need an...
# 19    unfortunately Sprint could not activate the ph...
# 20    The battery was old & had been over used becau...
# 21    pros-beautiful screen,capable of running chrom...
# 22    I purchased this phone in December as a christ...
# 23    Phone good just a little slow phone old but it...
# 24    Phone's speaker little low. Overall very happy...
# 25    the phone was great and in good condition. My ...
# 26    the reasons for the 3 star rating was it was i...
# 27                Phone works great. No problems at all
# 28         was not in good condition but does work good
# 29    Just... not good. The phone has great screen r...
#                             ...
# 70    This is a solidly-built unlocked phone that is...
# 71    Hola, compramos dos teléfonos y vienieron tota...
# 72    THIS CELLPHONE IS VERY EASY FOR USING, IT HAS ...
# 73    GRACIAS ME LLEGO EL PROCTO QUE COMPRE Y LLEVO ...
# 74    Freezes alot. But i bought primarily for playi...
# 75    The keys are a little hard to hit, and I didn'...
# 76    Preface: This is not what would be considered ...
# 77    We just received the phone a few days ago. Put...
# 78    I bought this phone as a Christmas present for...
# 79    The Phone is pretty good. I am using it with a...
# 80    loved everything about it. also it looks like ...
# 81    THIS IS A SOLUTION IF YOU WANT YOU ARE LOOKING...
# 82    This phone in an excellent phone at a great pr...
# 83    Have problems setting correct time on Nokia As...
# 84    This is a good phone although it seems to have...
# 85    I've been a long time user of the iPhone. I fi...
# 86    This phone, like all of Nokia's feature phones...
# 87                                             Love it.
# 88    Sorry it took so long to Reply or Review this ...
# 89    Bought it as a gift for my Mum and she loves i...
# 90    Incredible! This phone does not have Splaniish...
# 91                                                  BAD
# 92                                                 good
# 93           The battery died in less than 24/hours....
# 94                                   Excellent Product.
# 95                                            very well
# 96                        Cannot connect to GSM network
# 97    This cell phone exceeded my expectations, it's...
# 98    pros.. it works fine, its easy to use, not too...
# 99    I went through lots of reviews for different p...
# Name: Reviews, Length: 100, dtype: object

# %%
data_set['Rating'].unique()
# Out:
# array([5, 4, 1, 2, 3], dtype=int64)

# %%
unique_words=[]  
total_words=[]  
for i in data_set['Rating']:  
    i = str(i)  #float to char
    for j in i.split():  
        total_words.append(j)  
        if j not in unique_words:  
            unique_words.append(j)  
len(unique_words),len(total_words)
# Out:
# (5, 100)

# %%
from sklearn.model_selection import train_test_split  
# Split data into training and test sets  
X_train, X_test, y_train, y_test = train_test_split(x,y,random_state=0,test_size=.20)

# %%
from sklearn.feature_extraction.text import CountVectorizer  
# Fit the CountVectorizer to the training data  
vect = CountVectorizer().fit(X_train)  
len(vect.get_feature_names())
# Out:
# 973

# %%
# transform the documents in the training data to a document-term matrix  
X_train_vectorized = vect.transform(X_train)  
X_train_vectorized
# Out:
# <80x973 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2309 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import CountVectorizer  
# Fit the CountVectorizer to the training data  
vect = CountVectorizer().fit(X_train)  
len(vect.get_feature_names())  
3580  
# transform the documents in the training data to a document-term matrix  
X_train_vectorized = vect.transform(X_train)  
X_train_vectorized
# Out:
# <80x973 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2309 stored elements in Compressed Sparse Row format>
